# %%
import pytesseract
from PIL import Image

# %%
img = Image.open("/Users/yunsu/Desktop/test2.jpg")

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=338x116 at 0x10DDF4278>

# %%
print
# Out:
# iﬁﬁﬁﬁ’ﬂﬁlﬂiﬁiiglﬁé
