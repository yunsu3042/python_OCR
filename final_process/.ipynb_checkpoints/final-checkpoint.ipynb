# %%
import sys, os
import pytesseract
import copy
import string
import pickle
import cv2
import numpy as np
import sqlite3
sys.path.append('/Users/yunsu/mysite-projects/selenium')
sys.path.append('/Users/yunsu/Desktop/book_reading/study_by_self/final_process/calculation/py1040')
from matplotlib import pyplot as plt
from W2_ocr import *
from PIL import Image

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

import tensorflow

# %%
with open('/Users/yunsu/Desktop/book_reading/study_by_self/image/w2_dic2.pk1', 'rb') as f:
    w2_dic = pickle.load(f)

# %%
url = '/Users/yunsu/desktop/W2_OCR/W2/2014.png'

# %%
Image.open(url)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1692x1072 at 0x10FBA29B0>

# %%
img_list = pre_process(url,show=True)
page = ocr_process(img_list)
result = post_process1(page=page, w2_dic=w2_dic)
rdbs = post_process2(result=result)
insert_data(rdbs)
# Out:
# version for 2014
# post_process 1을 진행합니다.
# post_process 2을 시작합니다.
# 데이터 입력을 시작합니다.
# 데이터 입력을 마쳤습니다.

# %%
run taxes.py
# Out:
# ERROR:root:File `'taxes.py'` not found.

# %%
pwd
# Out:
# '/Users/yunsu/Desktop/book_reading/study_by_self/final_process'
